# %%
totals = 0

# %%
from passenger_info.main import personal_flight_booking
from Airplane.main import flight_booking
personal_flight_booking()
df = flight_booking()
df
# Out:
# Passenger 1 Details:
# Name: Jessica Phraoo
# Birthday: 2006-11-30
# Sex: F
# ID Number: 1100703557952
# Passport Number: -
# Destination: Phuket
# Available provinces for origin:
# ['Chiang Rai' 'Chiang Mai' 'Phuket' 'Hat Yai' 'Surat Thani' 'Udon Thani'
#  'Bangkok' 'Nakhon Ratchasima' 'Koh Samui' 'Krabi']
#
# Available provinces for destination:
# ['Phuket' 'Bangkok' 'Koh Samui' 'Chiang Rai' 'Krabi' 'Chiang Mai'
#  'Hat Yai' 'Surat Thani']
#
# Available flights from Chiang Rai to Koh Samui:
#     Flight Number   From City    To City        Airline Flight Status  \
# 139        TG0153  Chiang Rai  Koh Samui   PhraoAirAsia       On Time
# 613        TG0686  Chiang Rai  Koh Samui  Thai Meow Air       On Time
# 473        TG0527  Chiang Rai  Koh Samui     MJ Airways       Delayed
# 784        TG0876  Chiang Rai  Koh Samui   PhraoAirAsia       Delayed
# 673        TG0753  Chiang Rai  Koh Samui   PhraoAirAsia       Delayed
# ...

# %%
from class_flights.flight_booking_class import flight_booking_class
fbc = flight_booking_class()
print(f"Total price: {fbc} THB ")
# Out:
# You have selected flight TG0033 from Chiang Rai to Koh Samui
#
# Available seat classes and prices:
# Economy Class: 1497 THB
# Business Class: 4264 THB
# First Class: 9569 THB
#
# Booking successful! 3 seat(s) reserved in First Class.
# Total price: 28707 THB

# %%
from airline_baggage.main import main
baggage_fee = main()
print(f"The baggage fee is {round(baggage_fee)} THB.")
# Out:
# Baggage weight is (Kg) :  20.2
# The baggage fee is 1014 THB.

# %%
from food import main
main()
# Out:
# Menu (short flight in economy class):
# 1. Snack: 100 THB
# 2. Sandwich: 150 THB
# 3. Fruit Salad: 120 THB
# No food selected.

# %%
print(f"The total price to be paid is {baggage_fee+fbc} THB.")
# Out:
# The total price to be paid is 29721 THB.
